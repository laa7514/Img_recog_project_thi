# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.transforms.v2 as v2
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pathlib import Path
import time
import pandas
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import skimage as ski
from model_trainer import ModelTrainer
from datasets import ClassroomObjectsDataset
from models import FullyConnectedNet, SmallConvNet

# %%
csv_path = '/Users/anouknormann/Desktop/PracticalDeepLearning/stuhl.csv'
img_dir = '/Users/anouknormann/Desktop/PracticalDeepLearning/ImageProject/Objects_DataSet/stuhl_umbenannt_reduziert'
img_ds = ClassroomObjectsDataset(csv_path, img_dir)

img, label = img_ds.__getitem__(4)
# Out:
# tensor([1])

# %%
transforms2 = v2.Compose([
    #v2.RandomResizedCrop(size=(224, 224), antialias=True),
    v2.RandomHorizontalFlip(p=0.5),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

out_2 = transforms2(img)
img_asarray= img.permute(1, 2, 0).numpy()
imgplot = plt.imshow(img_asarray)
plt.show()

# %%
transforms = v2.Compose([
    #v2.RandomResizedCrop(size=(224, 224), antialias=True),
    v2.RandomHorizontalFlip(p=0.5),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    v2.Resize((245, 245)),
])

# %%
out = np.asarray(transforms(img))

# %%
out = transforms(img)
out_asarray= out.permute(1, 2, 0).numpy()
imgplot = plt.imshow(out_asarray)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
